# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:Christopher Noel
# * Student pace:Full time
# * Instructor name: Maryann Mwikali

# %% [markdown]
# ### EDA (Exploratory Data Analysis)
# This a process whereby we are to dissect our "data" by loading it into a data frame , this is done so as to enable us **understand the data , gain insights into the data structures, variable and basic properties**
# But before we begin we will have to include some technical tools to help us ie{**libraries**}

# %% [markdown]
# #### Libraries
# (why do we need libraries)= They provide a wide range of tools and modules for various tasks making it easier to work on specific tasks
#  **pandas as pd - data analysis & manipulation**
#  **numpy as np - numerical computing**
#  **matplotlib.pyplot as plt - creates static,interactive & animated visuals **
#  **seaborn as sns - proides high level interface for drawing interactive statistical graphs**

# %%
#1ST Step in EDA= importing of necessary librarie
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# 2ND Step in EDA =reading dataset
df = pd.read_csv("data/Aviation_Data.csv", low_memory=False)
df
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20001218X45444           Accident      SEA87LA080  1948-10-24
# 1      20001218X45447           Accident      LAX94LA336  1962-07-19
# 2      20061025X01555           Accident      NYC07LA005  1974-08-30
# 3      20001218X45448           Accident      LAX96LA321  1977-06-19
# 4      20041105X01764           Accident      CHI79FA064  1979-08-02
# ...               ...                ...             ...         ...
# 90343  20221227106491           Accident      ERA23LA093  2022-12-26
# 90344  20221227106494           Accident      ERA23LA095  2022-12-26
# 90345  20221227106497           Accident      WPR23LA075  2022-12-26
# 90346  20221227106498           Accident      WPR23LA076  2022-12-26
# 90347  20221230106513           Accident      ERA23LA097  2022-12-29
#
#               Location        Country   Latitude   Longitude Airport.Code  \
# ...

# %% [markdown]
# ### 3rd EDA=Analysing the data(data understanding)
# In this part we will basically be basically looking at the basic features of our data set ie{**what is in the dataset,type of data(boolean/integer),no.of rows/columns}

# %%
# summary of the data frame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90348 entries, 0 to 90347
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      90348 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Latitude                34382 non-null  object
#  7   Longitude               34373 non-null  object
#  8   Airport.Code            50249 non-null  object
#  9   Airport.Name            52790 non-null  object
#  10  Injury.Severity         87889 non-null  object
#  11  Aircraft.damage         85695 non-null  object
#  12  Aircraft.Category       32287 non-null  object
#  13  Registration.Number     87572 non-null  object
# ...

# %%
#finding dimensions of the dataframe
df.shape
# Out:
# (90348, 31)

# %%
# finding the first(20) rows of the data frame
df.head(20)
# Out:
#           Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0   20001218X45444           Accident      SEA87LA080  1948-10-24
# 1   20001218X45447           Accident      LAX94LA336  1962-07-19
# 2   20061025X01555           Accident      NYC07LA005  1974-08-30
# 3   20001218X45448           Accident      LAX96LA321  1977-06-19
# 4   20041105X01764           Accident      CHI79FA064  1979-08-02
# 5   20170710X52551           Accident      NYC79AA106  1979-09-17
# 6   20001218X45446           Accident      CHI81LA106  1981-08-01
# 7   20020909X01562           Accident      SEA82DA022  1982-01-01
# 8   20020909X01561           Accident      NYC82DA015  1982-01-01
# 9   20020909X01560           Accident      MIA82DA029  1982-01-01
# 10  20020909X01559           Accident      FTW82DA034  1982-01-01
# 11  20020909X01558           Accident      ATL82DKJ10  1982-01-01
# 12  20020917X02148           Accident      FTW82FRJ07  1982-01-02
# ...

# %%
# finding the last(20)rows of the data frame
df.tail(20)
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 90328  20221213106455           Accident      WPR23LA065  2022-12-13
# 90329  20221215106461           Accident      ERA23LA089  2022-12-13
# 90330  20221220106480           Accident      WPR23LA072  2022-12-13
# 90331  20221214106459           Accident      GAA23WA042  2022-12-14
# 90332  20221215106463           Accident      ERA23LA090  2022-12-14
# 90333  20221215106462           Accident      CEN23LA064  2022-12-15
# 90334  20221219106474           Accident      ANC23LA009  2022-12-15
# 90335  20221219106475           Accident      WPR23LA069  2022-12-15
# 90336  20221219106470           Accident      ERA23LA091  2022-12-16
# 90337  20221227106496           Accident      WPR23LA074  2022-12-17
# 90338  20221219106472           Accident      DCA23LA096  2022-12-18
# 90339  20221219106477           Accident      WPR23LA071  2022-12-18
# 90340  20221221106483           Accident      CEN23LA067  2022-12-21
# ...

# %%
# finding the column labels of the data frame
df.columns
# Out:
# Index(['Event.Id', 'Investigation.Type', 'Accident.Number', 'Event.Date',
#        'Location', 'Country', 'Latitude', 'Longitude', 'Airport.Code',
#        'Airport.Name', 'Injury.Severity', 'Aircraft.damage',
#        'Aircraft.Category', 'Registration.Number', 'Make', 'Model',
#        'Amateur.Built', 'Number.of.Engines', 'Engine.Type', 'FAR.Description',
#        'Schedule', 'Purpose.of.flight', 'Air.carrier', 'Total.Fatal.Injuries',
#        'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured',
#        'Weather.Condition', 'Broad.phase.of.flight', 'Report.Status',
#        'Publication.Date'],
#       dtype='object')

# %% [markdown]
# ## Data Cleaning
# **NOTE**;this is the most crucial and extensive part of our project;
# **WHY** we will now begin carefully and slowly nitpicking our data because after having a general overview of the information
# -We decide which information in **dataframe** actually helps= **adding value to our insights for future planning,increase overall productivity and allow for the highest quality information in your decision-making**
# -the processes includes;{ **droping rows/columns,filling missing values,dealing with outliers,correcting errors,handling duplicates,data transformation,feature engineering and Data integration}**
# -At the end of this we will have **"perfect_dataFrame"** which is of good data quality,from which we can depict graphs,has a good documentation & **is actually relevant and can provide keen and extensive insights**

# %%
#  return boolean series finding duplicated rows
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 90343    False
# 90344    False
# 90345    False
# 90346    False
# 90347    False
# Length: 90348, dtype: bool

# %%
df.duplicated(subset="Event.Id").value_counts()
# Out:
# False    87952
# True      2396
# dtype: int64

# %% [markdown]
# ### finding overall % of missing values in columns
# this will help us establish which of the columns has the highest number of missing values and if whether they have an impact to our analysis.This processes will best decide which relevant/irrelevant columns **can be filled/dropped,imputated**

# %%
# finding missing in column(%)
df.isnull().mean()*100
# Out:
# Event.Id                   1.614867
# Investigation.Type         0.000000
# Accident.Number            1.614867
# Event.Date                 1.614867
# Location                   1.672422
# Country                    1.865011
# Latitude                  61.944924
# Longitude                 61.954886
# Airport.Code              44.382831
# Airport.Name              41.570372
# Injury.Severity            2.721698
# Aircraft.damage            5.150086
# Aircraft.Category         64.263736
# Registration.Number        3.072564
# Make                       1.684597
# Model                      1.716695
# Amateur.Built              1.727764
# Number.of.Engines          8.348829
# Engine.Type                9.447913
# FAR.Description           64.555939
# Schedule                  86.073848
# Purpose.of.flight          8.468367
# Air.carrier               81.573471
# Total.Fatal.Injuries      14.233851
# Total.Serious.Injuries    15.461327
# Total.Minor.Injuries      14.822686
# ...

# %%
another_1=df.copy()

# %%
df = another_1.copy()

# %%
df.shape
# Out:
# (90348, 31)

# %%
# finalising the columns with missing values beyond 60% & their relevance
#dropping columns 
df.drop(columns = ["Schedule", "FAR.Description", "Longitude", "Latitude", "Location", "Air.carrier"], inplace=True)

# %%
# dropping columns{BASED ON RELEVANCE}
df.isnull().mean()*100
# Out:
# Event.Id                   1.614867
# Investigation.Type         0.000000
# Accident.Number            1.614867
# Event.Date                 1.614867
# Country                    1.865011
# Airport.Code              44.382831
# Airport.Name              41.570372
# Injury.Severity            2.721698
# Aircraft.damage            5.150086
# Aircraft.Category         64.263736
# Registration.Number        3.072564
# Make                       1.684597
# Model                      1.716695
# Amateur.Built              1.727764
# Number.of.Engines          8.348829
# Engine.Type                9.447913
# Purpose.of.flight          8.468367
# Total.Fatal.Injuries      14.233851
# Total.Serious.Injuries    15.461327
# Total.Minor.Injuries      14.822686
# Total.Uninjured            8.158454
# Weather.Condition          6.586753
# Broad.phase.of.flight     31.681941
# Report.Status              8.677558
# Publication.Date          18.471909
# dtype: float64

# %%
# do not add actionable insights for analysis
df.drop(columns = ['Airport.Name'],inplace=True)

# %%
# final confirmation of relevant columns
df.isnull().mean()*100
# Out:
# Event.Id                   1.614867
# Investigation.Type         0.000000
# Accident.Number            1.614867
# Event.Date                 1.614867
# Country                    1.865011
# Airport.Code              44.382831
# Injury.Severity            2.721698
# Aircraft.damage            5.150086
# Aircraft.Category         64.263736
# Registration.Number        3.072564
# Make                       1.684597
# Model                      1.716695
# Amateur.Built              1.727764
# Number.of.Engines          8.348829
# Engine.Type                9.447913
# Purpose.of.flight          8.468367
# Total.Fatal.Injuries      14.233851
# Total.Serious.Injuries    15.461327
# Total.Minor.Injuries      14.822686
# Total.Uninjured            8.158454
# Weather.Condition          6.586753
# Broad.phase.of.flight     31.681941
# Report.Status              8.677558
# Publication.Date          18.471909
# dtype: float64

# %%
# summary of my cleaned data frame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90348 entries, 0 to 90347
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      90348 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Country                 88663 non-null  object
#  5   Airport.Code            50249 non-null  object
#  6   Injury.Severity         87889 non-null  object
#  7   Aircraft.damage         85695 non-null  object
#  8   Aircraft.Category       32287 non-null  object
#  9   Registration.Number     87572 non-null  object
#  10  Make                    88826 non-null  object
#  11  Model                   88797 non-null  object
#  12  Amateur.Built           88787 non-null  object
#  13  Number.of.Engines       82805 non-null  float64
# ...

# %%
# Gaining descriptive statistics from the data frame
df.describe()
# Out:
#        Number.of.Engines  Total.Fatal.Injuries  Total.Serious.Injuries  \
# count       82805.000000          77488.000000            76379.000000
# mean            1.146585              0.647855                0.279881
# std             0.446510              5.485960                1.544084
# min             0.000000              0.000000                0.000000
# 25%             1.000000              0.000000                0.000000
# 50%             1.000000              0.000000                0.000000
# 75%             1.000000              0.000000                0.000000
# max             8.000000            349.000000              161.000000
#
#        Total.Minor.Injuries  Total.Uninjured
# count          76956.000000     82977.000000
# mean               0.357061         5.325440
# std                2.235625        27.913634
# min                0.000000         0.000000
# 25%                0.000000         0.000000
# 50%                0.000000         1.000000
# ...

# %%
# dropping row with missing values only for object columns
df.dropna(subset = df.select_dtypes(include=['object']).columns,inplace=True)

# %%
df.shape
# Out:
# (3999, 24)

# %%
df.isnull().mean()*100
# Out:
# Event.Id                   0.000000
# Investigation.Type         0.000000
# Accident.Number            0.000000
# Event.Date                 0.000000
# Country                    0.000000
# Airport.Code               0.000000
# Injury.Severity            0.000000
# Aircraft.damage            0.000000
# Aircraft.Category          0.000000
# Registration.Number        0.000000
# Make                       0.000000
# Model                      0.000000
# Amateur.Built              0.000000
# Number.of.Engines          0.125031
# Engine.Type                0.000000
# Purpose.of.flight          0.000000
# Total.Fatal.Injuries      55.063766
# Total.Serious.Injuries    53.913478
# Total.Minor.Injuries      47.011753
# Total.Uninjured           12.503126
# Weather.Condition          0.000000
# Broad.phase.of.flight      0.000000
# Report.Status              0.000000
# Publication.Date           0.000000
# dtype: float64

# %% [markdown]
# ## identifying&handling outliers
# **Outliers**-data points that significantly differ from the rest of the dataset
# in this step we to spot what are the features that do not add value to the continuos data.we do this by identifying outliers by using statistical methods in this case **{Interquartile range}**
# **Treatment** we decide whether to remove, cap or transform outliers

# %%
#identifying outliers in our continuos data
Q1 = df['Total.Fatal.Injuries'].quantile(0.25)
Q3 = df['Total.Fatal.Injuries'].quantile(0.75)
IQR = Q3 - Q1
outliers = df[(df['Total.Fatal.Injuries'] < (Q1 - 1.5 * IQR)) | (df['Total.Fatal.Injuries'] > (Q3 + 1.5 * IQR))]
outliers
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 13     20020917X02134           Accident      FTW82FRA14  1982-01-02
# 26     20020917X01720           Accident      ATL82FA033  1982-01-03
# 37     20020917X02304           Accident      LAX82FUM06  1982-01-05
# 54     20020917X02414           Accident      MIA82FLD14  1982-01-08
# 55     20020917X01881           Accident      CHI82FA024  1982-01-08
# ...               ...                ...             ...         ...
# 63828  20071219X01978           Accident      SEA08FA042  2007-12-10
# 63833  20071227X01998           Accident      NYC08LA059  2007-12-12
# 63871  20080102X00007           Accident      CHI08FA053  2007-12-20
# 63899  20080108X00030           Accident      CHI08FA055  2007-12-27
# 63909  20080114X00045           Accident      LAX08FA043  2007-12-30
#
#              Country Airport.Code Injury.Severity Aircraft.damage  \
# 13     United States          T72        Fatal(1)       Destroyed
# ...

# %%
Q1 = df['Number.of.Engines'].quantile(0.25)
Q3 = df['Number.of.Engines'].quantile(0.75)
IQR = Q3 - Q1
outliers_1 = df[(df['Number.of.Engines'] < (Q1 - 1.5 * IQR)) | (df['Number.of.Engines'] > (Q3 + 1.5 * IQR))]
outliers_1
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 8      20020909X01561           Accident      NYC82DA015  1982-01-01
# 26     20020917X01720           Accident      ATL82FA033  1982-01-03
# 45     20020917X02423           Accident      MKC82DA016  1982-01-06
# 53     20020917X02141           Accident      FTW82FRG20  1982-01-07
# 65     20020917X01994           Accident      FTW82DA038  1982-01-09
# ...               ...                ...             ...         ...
# 63834  20080123X00097           Accident      NYC08CA073  2007-12-12
# 63836  20080123X00094           Accident      NYC08CA072  2007-12-13
# 63841  20080213X00187           Accident     NYC08LA062B  2007-12-14
# 63862  20080312X00298           Accident      MIA08CA046  2007-12-19
# 63899  20080108X00030           Accident      CHI08FA055  2007-12-27
#
#              Country Airport.Code Injury.Severity Aircraft.damage  \
# 8      United States          N58       Non-Fatal     Substantial
# ...

# %%
Q1 = df['Total.Serious.Injuries'].quantile(0.25)
Q3 = df['Total.Serious.Injuries'].quantile(0.75)
IQR = Q3 - Q1
outliers_2 = df[(df['Total.Serious.Injuries'] < (Q1 - 1.5 * IQR)) | (df['Total.Serious.Injuries'] > (Q3 + 1.5 * IQR))]
outliers_2
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 44     20020917X01651           Accident      ANC82FA012  1982-01-05
# 55     20020917X01881           Accident      CHI82FA024  1982-01-08
# 82     20020917X02111           Accident      FTW82FPA10  1982-01-12
# 93     20020917X02538           Accident      NYC82FA021  1982-01-15
# 141    20020917X02295           Accident      LAX82FUJ25  1982-01-21
# ...               ...                ...             ...         ...
# 63776  20071130X01879           Accident      DFW08FA038  2007-11-27
# 63777  20080109X00035           Accident      NYC08CA048  2007-11-28
# 63806  20080122X00089           Accident      CHI08CA020  2007-12-05
# 63847  20071226X01986           Accident      DEN08LA041  2007-12-15
# 63899  20080108X00030           Accident      CHI08FA055  2007-12-27
#
#              Country Airport.Code Injury.Severity Aircraft.damage  \
# 44     United States          BET       Non-Fatal     Substantial
# ...

# %%
Q1 = df['Total.Minor.Injuries'].quantile(0.25)
Q3 = df['Total.Minor.Injuries'].quantile(0.75)
IQR = Q3 - Q1
outliers_3 = df[(df['Total.Minor.Injuries'] < (Q1 - 1.5 * IQR)) | (df['Total.Minor.Injuries'] > (Q3 + 1.5 * IQR))]
outliers_3
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 144    20020917X01749           Accident      ATL82FKJ11  1982-01-21
# 229    20020917X01923           Accident      DEN82DA029  1982-02-03
# 552    20020917X02548           Accident      NYC82FFJ12  1982-03-12
# 612    20020917X02375           Accident      MIA82DA089  1982-03-18
# 769    20020917X01854           Accident      CHI82DA114  1982-04-05
# 1180   20020917X02915           Accident      CHI82DA164  1982-05-13
# 1343   20020917X03653           Accident      LAX82FA195  1982-05-26
# 1452   20020917X03874           Accident      MKC82FA096  1982-06-05
# 1526   20020917X04094           Accident      SEA82DA086  1982-06-12
# 1695   20020917X02647           Accident      ANC82DA052  1982-06-24
# 1780   20020917X03827           Accident      MKC82DA112  1982-07-02
# 1970   20020917X02985           Accident      CHI82DA251  1982-07-16
# 2075   20020917X03516           Accident      LAX82AA274  1982-07-23
# ...

# %%
Q1 = df['Total.Uninjured'].quantile(0.25)
Q3 = df['Total.Uninjured'].quantile(0.75)
IQR = Q3 - Q1
outliers_4 = df[(df['Total.Uninjured'] < (Q1 - 1.5 * IQR)) | (df['Total.Uninjured'] > (Q3 + 1.5 * IQR))]
outliers_4
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 46     20020917X02157           Accident      LAX82DA039  1982-01-06
# 69     20020917X02158           Accident      LAX82DA041  1982-01-10
# 86     20020917X01996           Accident      FTW82DA040  1982-01-13
# 93     20020917X02538           Accident      NYC82FA021  1982-01-15
# 129    20020917X02397           Accident      MIA82FA034  1982-01-19
# ...               ...                ...             ...         ...
# 63747  20071207X01914           Accident      MIA08CA018  2007-11-18
# 63796  20071206X01909           Accident      SEA08LA041  2007-12-02
# 63841  20080213X00187           Accident     NYC08LA062B  2007-12-14
# 63877  20080124X00101           Accident      NYC08CA068  2007-12-22
# 63896  20071231X02008           Incident      DEN08IA044  2007-12-26
#
#              Country Airport.Code Injury.Severity Aircraft.damage  \
# 46     United States          MMH       Non-Fatal     Substantial
# ...

# %% [markdown]
# ## Handling missing values
# -some of the data present might have missing values
# -it is upto us to find the best mode of **imputation-missing data is filled in to create a complete data matrix that can be analysed using standard methods**
# -imputation can be done through-**mean,median,mode**
# -This is done so as to enable us keep our original data & key points to calculate keen insights that help in focusing on our objective

# %%
# filling missing values of continuos data
relevant_columns = ["Number.of.Engines", "Total.Fatal.Injuries", "Total.Serious.Injuries", "Total.Minor.Injuries", "Total.Uninjured"]
relevant_columns
# Out:
# ['Number.of.Engines',
#  'Total.Fatal.Injuries',
#  'Total.Serious.Injuries',
#  'Total.Minor.Injuries',
#  'Total.Uninjured']

# %%
# assigned list of columns and re_assigning missing values with their median
# used median because we spotted outliers

df[relevant_columns] = df[relevant_columns].fillna(df[relevant_columns].median())

# %%
#descriptive statistics of **cleaned dataFrame**
df.describe()
# Out:
#        Number.of.Engines  Total.Fatal.Injuries  Total.Serious.Injuries  \
# count        3999.000000           3999.000000             3999.000000
# mean            1.135034              0.226307                0.110278
# std             0.386452              3.717655                0.616670
# min             0.000000              0.000000                0.000000
# 25%             1.000000              0.000000                0.000000
# 50%             1.000000              0.000000                0.000000
# 75%             1.000000              0.000000                0.000000
# max             4.000000            228.000000               26.000000
#
#        Total.Minor.Injuries  Total.Uninjured
# count            3999.00000      3999.000000
# mean                0.27932         2.663916
# std                 1.15517        17.202312
# min                 0.00000         0.000000
# 25%                 0.00000         1.000000
# 50%                 0.00000         1.000000
# ...

# %%
# Confirmation of final missing values in both categorical and continuos data
df.isnull().sum()
# Out:
# Event.Id                  0
# Investigation.Type        0
# Accident.Number           0
# Event.Date                0
# Country                   0
# Airport.Code              0
# Injury.Severity           0
# Aircraft.damage           0
# Aircraft.Category         0
# Registration.Number       0
# Make                      0
# Model                     0
# Amateur.Built             0
# Number.of.Engines         0
# Engine.Type               0
# Purpose.of.flight         0
# Total.Fatal.Injuries      0
# Total.Serious.Injuries    0
# Total.Minor.Injuries      0
# Total.Uninjured           0
# Weather.Condition         0
# Broad.phase.of.flight     0
# Report.Status             0
# Publication.Date          0
# dtype: int64

# %% [markdown]
# ## .groupby() and aggregation methods
# -this helps us understand the different relationships between what cause accidents and what is the most aircraft most prone to failure
# -grouping the data using the groupby() method is highly beneficial, especially for categorical variables that may provide insight into how different factors influence injuries, fatalities, or other metrics.

# %%
df
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 8      20020909X01561           Accident      NYC82DA015  1982-01-01
# 13     20020917X02134           Accident      FTW82FRA14  1982-01-02
# 18     20020917X02481           Accident      NYC82DA016  1982-01-02
# 20     20020917X01894           Accident      CHI82FEC08  1982-01-02
# 21     20020917X01776           Accident      CHI82DA020  1982-01-02
# ...               ...                ...             ...         ...
# 63899  20080108X00030           Accident      CHI08FA055  2007-12-27
# 63901  20080111X00041           Accident      DFW08CA051  2007-12-28
# 63909  20080114X00045           Accident      LAX08FA043  2007-12-30
# 63910  20080129X00122           Accident      CHI08CA057  2007-12-30
# 63911  20080125X00106           Accident      SEA08CA056  2007-12-31
#
#              Country Airport.Code Injury.Severity Aircraft.damage  \
# 8      United States          N58       Non-Fatal     Substantial
# ...

# %%
# Group by Aircraft Category and calculate mean number of accidents
VIZ = df.groupby('Aircraft.Category').agg({
    'Total.Fatal.Injuries': 'mean',
    'Total.Uninjured': 'mean'
}).reset_index()
VIZ
# Out:
#   Aircraft.Category  Total.Fatal.Injuries  Total.Uninjured
# 0          Airplane              0.235039         2.754942
# 1           Balloon              0.000000         2.000000
# 2             Blimp              0.000000         1.666667
# 3            Glider              0.040000         1.000000
# 4         Gyrocraft              0.000000         0.956522
# 5        Helicopter              0.142292         1.671937

# %%
VIZ = df[df['Aircraft.Category'] == 'Airplane'].groupby('Make').agg({
    'Total.Fatal.Injuries': 'mean',
    'Total.Uninjured': 'mean'
}).reset_index()
VIZ
# Out:
#                   Make  Total.Fatal.Injuries  Total.Uninjured
# 0    Ac Mfg & Dev't Co              0.000000         1.000000
# 1               Ackert              0.000000         1.000000
# 2           Acro Sport              0.000000         1.000000
# 3               Adkins              0.000000         1.000000
# 4       Aero Commander              0.066667         1.866667
# ..                 ...                   ...              ...
# 489         Wroblewski              0.000000         1.000000
# 490     Wsk Pzl Mielec              0.000000         1.000000
# 491           Yakovlev              1.000000         0.500000
# 492              Young              0.000000         1.000000
# 493             Zenair              0.000000         2.000000
#
# [494 rows x 3 columns]

# %%
mon = df[df['Aircraft.Category'] == 'Airplane'].groupby('Model').agg({
    'Total.Fatal.Injuries': 'mean',
    'Total.Uninjured': 'mean'
}).reset_index()
mon
# Out:
#                     Model  Total.Fatal.Injuries  Total.Uninjured
# 0                    0-1A                   0.0         2.000000
# 1                   0-47B                   0.0         5.000000
# 2                  1.131E                   0.0         1.000000
# 3                     100                   0.0         1.750000
# 4                     108                   0.0         2.000000
# ...                   ...                   ...              ...
# 1218         Zenith Tri-Z                   0.0         1.000000
# 1219  Zodiac (CH-601-HDS)                   0.0         1.000000
# 1220         Zodiac 601XL                   0.0         1.333333
# 1221    Zodiac CH 601 HDS                   0.0         1.000000
# 1222            sportstar                   0.0         2.000000
#
# [1223 rows x 3 columns]

# %%
# #Group by Country and calculate mean number of accidents
VIZ_1 = df.groupby('Country').agg({
    'Total.Fatal.Injuries': 'mean',
    'Total.Uninjured': 'mean'
}).reset_index()
VIZ_1
# Out:
#           Country  Total.Fatal.Injuries  Total.Uninjured
# 0  GULF OF MEXICO              0.000000         1.000000
# 1     HIGH ISLAND              0.000000         4.000000
# 2           Haiti             13.000000         1.000000
# 3        Honduras              0.000000         3.000000
# 4           Japan              0.000000       258.000000
# 5         MISSING              2.000000         0.000000
# 6     Puerto Rico              0.000000       226.333333
# 7   United States              0.223058         2.432832

# %%
countries = VIZ_1['Country']
fatal_injuries = VIZ_1['Total.Fatal.Injuries']
uninjured = VIZ_1['Total.Uninjured']

# Plot
fig, ax = plt.subplots(figsize=(10, 6))

# Create stacked bar plot
bar_width = 0.6
index = np.arange(len(countries))

ax.bar(index, fatal_injuries, bar_width, label='Fatal Injuries', color='red')
ax.bar(index, uninjured, bar_width, bottom=fatal_injuries, label='Uninjured', color='green')

# Adding labels, title, and legend
ax.set_xlabel('Country')
ax.set_ylabel('Number of People')
ax.set_title('Fatality by Country')
ax.set_xticks(index)
ax.set_xticklabels(countries, rotation=90)  # Rotate country names for better visibility
ax.legend()

# Tight layout for better fit
plt.tight_layout()

# Show the plot
plt.show()

# %%
# set width of bar 
barWidth = 0.25
fig = plt.subplots(figsize =(12, 8)) 

# set height of bar 
Total.Fatal.Injuries = [12, 30, 1, 8, 22] 
Total.Uninjured = [28, 6, 16, 5, 10] 


# Set position of bar on X axis 
br1 = np.arange(len(Total.Fatal.Injuries)) 
br2 = [x + barWidth for x in br1] 

# Make the plot
plt.bar(br1, Total.Fatal.Injuries, color ='r', width = barWidth, 
        edgecolor ='grey', label ='Total.Fatal.Injuries') 
plt.bar(br2, Total.Uninjured, color ='g', width = barWidth, 
        edgecolor ='grey', label ='Total.Uninjured') 

# Adding Xticks 
plt.xlabel('Country', fontweight ='bold', fontsize = 15) 
plt.ylabel('Fatalities', fontweight ='bold', fontsize = 15) 
plt.xticks([r + barWidth for r in range(len(Total.Uninjured))], 
        ['2015', '2016', '2017', '2018', '2019'])

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-147-fd3874255968> in <module>
#       4
#       5 # set height of bar
# ----> 6 Total.Fatal.Injuries = [12, 30, 1, 8, 22]
#       7 Total.Uninjured = [28, 6, 16, 5, 10]
#       8
#
# NameError: name 'Total' is not defined

# %%
VIZ_1.sort_values(by=["Total.Uninjured"])
# Out:
#           Country  Total.Fatal.Injuries  Total.Uninjured
# 5         MISSING              2.000000         0.000000
# 0  GULF OF MEXICO              0.000000         1.000000
# 2           Haiti             13.000000         1.000000
# 7   United States              0.223058         2.432832
# 3        Honduras              0.000000         3.000000
# 1     HIGH ISLAND              0.000000         4.000000
# 6     Puerto Rico              0.000000       226.333333
# 4           Japan              0.000000       258.000000

# %%
# trail barchart **axis??
cuz = df.groupby('Country').agg({
    'Total.Fatal.Injuries': 'mean',
     'Total.Uninjured': 'mean'
}).reset_index()
cuz
fig,ax=plt.subplots(figsize=(12,10))
ax.bar(x=cuz.Country, height=cuz['Total.Fatal.Injuries'])
ax.bar(x=cuz.Country, height=cuz['Total.Uninjured'])
# Out:
# <BarContainer object of 8 artists>

# %%
# barchart *basis
fig,ax=plt.subplots(figsize=(12,10))
ax.bar(x=cuz.Country, height=list(cuz['Total.Serious.Injuries'], cuz['Total.Fatal.Injuries']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total.Serious.Injuries'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-150-9a77750ae56f> in <module>
# ...

# %%
#Group by Make and calculate mean number of accidents * to be nulled
VIZ_2 = df.groupby('Make').agg({
    'Total.Fatal.Injuries': 'mean',
    'Total.Uninjured': 'mean'
}).reset_index()
VIZ_2
# Out:
#                   Make  Total.Fatal.Injuries  Total.Uninjured
# 0    Ac Mfg & Dev't Co              0.000000         1.000000
# 1               Ackert              0.000000         1.000000
# 2           Acro Sport              0.000000         1.000000
# 3               Adkins              0.000000         1.000000
# 4       Aero Commander              0.066667         1.866667
# ..                 ...                   ...              ...
# 555         Wroblewski              0.000000         1.000000
# 556     Wsk Pzl Mielec              0.000000         1.000000
# 557           Yakovlev              1.000000         0.500000
# 558              Young              0.000000         1.000000
# 559             Zenair              0.000000         2.000000
#
# [560 rows x 3 columns]

# %%
#Group by Model and calculate mean number of accidents* to be nulled
VIZ_3 = df.groupby('Model').agg({
    'Total.Fatal.Injuries': 'mean',
    'Total.Uninjured': 'mean'
}).reset_index()
VIZ_3

# %%
#Group by Amateur built  and calculate mean number of accidents
VIZ_4 = df.groupby('Amateur.Built').agg({
    'Total.Fatal.Injuries': 'mean',
    'Total.Uninjured': 'mean'
}).reset_index()
VIZ_4
# Out:
#   Amateur.Built  Total.Fatal.Injuries  Total.Uninjured
# 0            No              0.239499         2.836718
# 1           Yes              0.108911         1.126238

# %%
sizes_normalized = [float(i)/sum(VIZ_4['Total.Fatal.Injuries']) * 100 for i in VIZ_4['Total.Fatal.Injuries']]

# %%
# PIE CHART *basis
fig, ax=plt.subplots()
ax.pie(sizes_normalized, autopct='%1.1f%%', labels=VIZ_4["Amateur.Built"])
ax.set_aspect('equal')

# %%
#Group by weather conditon and cause to Aircraft damage
VIZ_5 = df.groupby(['Weather.Condition', 'Aircraft.damage']).size().unstack(fill_value=0)
VIZ_5
# Out:
# Aircraft.damage    Destroyed  Minor  Substantial
# Weather.Condition
# IMC                       86     14          104
# UNK                        3      1           12
# VMC                      367     91         3321

# %%
#.pie=piechart
fig, ax=plt.subplots()
ax.pie
# Out:
# <bound method Axes.pie of <AxesSubplot:>>

# %% [markdown]
# ##  Data Visualizations
# -Here we are finalising the story of our data.we use two of the imported libraries **sns and plt**.
# -**Visualizations** :provide proof of aggregation that was done above ,make it easier to identify patterns, trends and outliers in large data sets.

# %%
# creating a histogram to see distribution of the data set
VIZ_1.plot(kind='bar', x='Country', figsize=(10, 8))

# Add labels and title
plt.ylabel('Mean Value')
plt.title('Highest  Injuries and Uninjured by Country')
plt.xticks(rotation=50)
plt.tight_layout()

# Show the plot
plt.show()

# %%
df
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 8      20020909X01561           Accident      NYC82DA015  1982-01-01
# 13     20020917X02134           Accident      FTW82FRA14  1982-01-02
# 18     20020917X02481           Accident      NYC82DA016  1982-01-02
# 20     20020917X01894           Accident      CHI82FEC08  1982-01-02
# 21     20020917X01776           Accident      CHI82DA020  1982-01-02
# ...               ...                ...             ...         ...
# 63899  20080108X00030           Accident      CHI08FA055  2007-12-27
# 63901  20080111X00041           Accident      DFW08CA051  2007-12-28
# 63909  20080114X00045           Accident      LAX08FA043  2007-12-30
# 63910  20080129X00122           Accident      CHI08CA057  2007-12-30
# 63911  20080125X00106           Accident      SEA08CA056  2007-12-31
#
#              Country Airport.Code Injury.Severity Aircraft.damage  \
# 8      United States          N58       Non-Fatal     Substantial
# ...

# %%
correlation_df = df.select_dtypes(include=['number'])
correlation_df.corr()
# Out:
#                         Number.of.Engines  Total.Fatal.Injuries  \
# Number.of.Engines                1.000000              0.149688
# Total.Fatal.Injuries             0.149688              1.000000
# Total.Serious.Injuries           0.116974              0.689223
# Total.Minor.Injuries             0.053322              0.007468
# Total.Uninjured                  0.297518             -0.005362
#
#                         Total.Serious.Injuries  Total.Minor.Injuries  \
# Number.of.Engines                     0.116974              0.053322
# Total.Fatal.Injuries                  0.689223              0.007468
# Total.Serious.Injuries                1.000000              0.105976
# Total.Minor.Injuries                  0.105976              1.000000
# Total.Uninjured                       0.001844              0.099493
#
#                         Total.Uninjured
# Number.of.Engines              0.297518
# Total.Fatal.Injuries          -0.005362
# Total.Serious.Injuries         0.001844
# ...

# %%
sns.heatmap(correlation_df.corr(), annot = True)
plt.title('Correlation Matrix')
plt.show()

# %%
correlation_df = df.select_dtypes(include=['number'])
correlation_matrix = correlation_df.corr()

# Create heatmap with customized color bar
sns.heatmap(correlation_matrix, annot=True, cbar_kws={ 'label': 'Correlation Coefficient'})
plt.title('Correlation Matrix')
plt.show()

# %%
# Get the top 10 airplane makes by accident count
top_15_makes = df['Make'].value_counts().nlargest(10).index

# Filter the DataFrame to include only the top 10 makes
top_15_df = df[df['Make'].isin(top_15_makes)]

# Create the plot
plt.figure(figsize=(10, 6))
sns.countplot(data=top_15_df, x='Make', order=top_15_makes)
plt.title('Top 15 Airplane Makes and the Number of Accidents')
plt.xticks(rotation=45, ha='right')  # Rotate x labels for better readability
plt.show()
